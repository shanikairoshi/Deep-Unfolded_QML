# %% [markdown]
# <a href="https://colab.research.google.com/github/shanikairoshi/QML-and-Deep-Unfolded_QML/blob/main/D_QNN_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
iris_df = pd.read_csv('/content/training_resultsIrisDQNN.csv')
adhoc_df = pd.read_csv('/content/training_resultsAdhocDQNN.csv')
genomic_df = pd.read_csv('/content/training_resultsGenomicDQNN.csv')
breastcancer_df = pd.read_csv('/content/training_results_BreatCancerDQNN.csv')

# Dictionary to hold the dataframes
datasets = {
    "Iris": iris_df,
    "Adhoc": adhoc_df,
    "Genomic": genomic_df,
    "BreastCancer": breastcancer_df
}

# Plot 1: Training Accuracy
plt.figure(figsize=(10, 5))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Training Accuracy'], label=dataset_name)
plt.title('Training Accuracy vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Training Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# Plot 2: Test Accuracy
plt.figure(figsize=(10, 5))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Test Accuracy'], label=dataset_name)
plt.title('Test Accuracy vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Test Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# Plot 3: Objective Function Value
plt.figure(figsize=(10, 5))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Objective Function Value'], label=dataset_name)
plt.title('Objective Function Value vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# prompt: draw a line in 75 for trainng accuracy plto

import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
iris_df = pd.read_csv('/content/training_resultsIrisDQNN.csv')
adhoc_df = pd.read_csv('/content/training_resultsAdhocDQNN.csv')
genomic_df = pd.read_csv('/content/training_resultsGenomicDQNN.csv')
breastcancer_df = pd.read_csv('/content/training_results_BreatCancerDQNN.csv')

# Dictionary to hold the dataframes
datasets = {
    "Iris": iris_df,
    "Adhoc": adhoc_df,
    "Genomic": genomic_df,
    "BreastCancer": breastcancer_df
}

# Plot 1: Training Accuracy
plt.figure(figsize=(5, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Training Accuracy'], label=dataset_name)
plt.title('D-QNN Training Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Training Accuracy')
plt.axhline(y=75, color='blue', linestyle='--', label='Iris QNN')
plt.axhline(y=99, color='orange', linestyle='--', label='Adhoc QNN')
plt.axhline(y=70, color='green', linestyle='--', label='Genomic QNN')
plt.axhline(y=82, color='red', linestyle='--', label='Breast Cancer QNN')
plt.legend()
#plt.tight_layout()
plt.show()

# Plot 2: Test Accuracy
plt.figure(figsize=(5, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Test Accuracy'], label=dataset_name)
plt.title('D-QNN Test Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Test Accuracy')
plt.axhline(y=40, color='blue', linestyle='--', label='Iris QNN')
plt.axhline(y=96.67, color='orange', linestyle='--', label='Adhoc QNN')
plt.axhline(y=75, color='green', linestyle='--', label='Genomic QNN')
plt.axhline(y=80, color='red', linestyle='--', label='Breast Cancer QNN')
plt.legend()
plt.tight_layout()
plt.show()

# Plot 3: Objective Function Value
plt.figure(figsize=(5, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Objective Function Value'], label=dataset_name)
plt.title('Objective Function Value vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')
plt.legend()
plt.tight_layout()
plt.show()

# Plot 4: Learning Rate
plt.figure(figsize=(5, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Learning Rate'], label=dataset_name)
plt.title('Learning Rate vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.legend()
plt.tight_layout()
plt.show()

# Plot 5: Perturbation Rate
plt.figure(figsize=(5, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Perturbation'], label=dataset_name)
plt.title('Perturbation Rate vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Perturbation Rate')
plt.legend()
plt.tight_layout()
plt.show()

# Data from the table
datasets = ['Adhoc', 'Iris', 'BreastCancer', 'Genomic']
qnn_train_acc = [99, 75, 82, 70]
qnn_test_acc = [96.67, 40, 80, 75]
dqnn_train_acc = [100, 76.25, 86, 79.5]
dqnn_test_acc = [96.67, 60, 82, 83]

# Create a plot for Training Accuracy
plt.figure(figsize=(5, 4))
plt.plot(datasets, qnn_train_acc, marker='o', linestyle='-', label='QNN Train Accuracy', color='gray')
plt.plot(datasets, dqnn_train_acc, marker='o', linestyle='--', label='DQNN Train Accuracy', color='black')
plt.title('QNN vs DQNN Training Accuracy')
plt.xlabel('Dataset')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.show()

# Create a plot for Test Accuracy
plt.figure(figsize=(5, 4))
plt.plot(datasets, qnn_test_acc, marker='o', linestyle='-', label='QNN Test Accuracy', color='gray')
plt.plot(datasets, dqnn_test_acc, marker='o', linestyle='--', label='DQNN Test Accuracy', color='black')
plt.title('QNN vs DQNN Test Accuracy')
plt.xlabel('Dataset')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
iris_df = pd.read_csv('/content/training_resultsIrisDQNN.csv')
adhoc_df = pd.read_csv('/content/training_resultsAdhocDQNN.csv')
genomic_df = pd.read_csv('/content/training_resultsGenomicDQNN.csv')
breastcancer_df = pd.read_csv('/content/training_results_BreatCancerDQNN.csv')

# Dictionary to hold the dataframes
datasets = {
    "Iris": iris_df,
    "Adhoc": adhoc_df,
    "Genomic": genomic_df,
    "BreastCancer": breastcancer_df
}

# Define colors for each dataset (muted, professional palette)
colors = {
    "Iris": "#2b83ba",          # blue
    "Adhoc": "#fdae61",         # orange
    "Genomic": "#abdda4",       # green
    "BreastCancer": "#d7191c"   # red
}

# Plot 1: Training Accuracy
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Training Accuracy'], label=f'{dataset_name} DQNN', color=colors[dataset_name])
plt.title('D-QNN Training Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Training Accuracy')
plt.axhline(y=75, color=colors["Iris"], linestyle='--', label='Iris QNN')
plt.axhline(y=99, color=colors["Adhoc"], linestyle='--', label='Adhoc QNN')
plt.axhline(y=70, color=colors["Genomic"], linestyle='--', label='Genomic QNN')
plt.axhline(y=82, color=colors["BreastCancer"], linestyle='--', label='Breast Cancer QNN')
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1), fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Training_Accuracy.png', dpi=300)  # Save plot
plt.show()

# Plot 2: Test Accuracy
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Test Accuracy'],label=f'{dataset_name} DQNN', color=colors[dataset_name])
plt.title('D-QNN Test Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Test Accuracy')
plt.axhline(y=40, color=colors["Iris"], linestyle='--', label='Iris QNN')
plt.axhline(y=96.67, color=colors["Adhoc"], linestyle='--', label='Adhoc QNN')
plt.axhline(y=75, color=colors["Genomic"], linestyle='--', label='Genomic QNN')
plt.axhline(y=80, color=colors["BreastCancer"], linestyle='--', label='Breast Cancer QNN')
plt.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Test_Accuracy.png', dpi=300)  # Save plot
plt.show()

# Plot 3: Objective Function Value
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Objective Function Value'], label=f'{dataset_name} DQNN', color=colors[dataset_name])
plt.title('Objective Function Value vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')
plt.legend(loc='upper right',  fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Objective_Function_Value.png', dpi=300)  # Save plot
plt.show()

# Plot 4: Learning Rate
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Learning Rate'], label=f'{dataset_name} DQNN', color=colors[dataset_name])
plt.title('Learning Rate vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Learning_Rate.png', dpi=300)  # Save plot
plt.show()

# Plot 5: Perturbation Rate
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Perturbation'], label=f'{dataset_name} DQNN', color=colors[dataset_name])
plt.title('Perturbation Rate vs Iterations')
plt.xlabel('Iteration')
plt.ylabel('Perturbation Rate')
plt.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Perturbation_Rate.png', dpi=300)  # Save plot
plt.show()

import matplotlib.pyplot as plt

# Data from the table
datasets = ['Adhoc', 'Iris', 'BreastCancer', 'Genomic']
qnn_train_acc = [99, 75, 82, 70]
qnn_test_acc = [96.67, 40, 80, 75]
dqnn_train_acc = [100, 76.25, 86, 79.5]
dqnn_test_acc = [96.67, 60, 82, 83]

# Define a color scheme using purple and cyan for good contrast
qnn_color = "#9467bd"  # Purple for QNN
dqnn_color = "#17becf"  # Cyan for DQNN

# Create a plot for Training Accuracy
plt.figure(figsize=(6, 4))
plt.plot(datasets, qnn_train_acc, marker='o', linestyle='-', label='QNN ', color=qnn_color)
plt.plot(datasets, dqnn_train_acc, marker='o', linestyle='--', label='DQNN ', color=dqnn_color)
plt.title('Comparison of QNN and DQNN Training Accuracy Across Datasets', fontsize=12)
plt.xlabel('Dataset', fontsize=10)
plt.ylabel('Training Accuracy (%)', fontsize=10)
plt.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# Create a plot for Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(datasets, qnn_test_acc, marker='o', linestyle='-', label='QNN', color=qnn_color)
plt.plot(datasets, dqnn_test_acc, marker='o', linestyle='--', label='DQNN', color=dqnn_color)
plt.title('Comparison of QNN and DQNN Test Accuracy Across Datasets', fontsize=12)
plt.xlabel('Dataset', fontsize=10)
plt.ylabel('Test Accuracy (%)', fontsize=10)
plt.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
iris_df = pd.read_csv('/content/training_resultsIrisDQNN.csv')
adhoc_df = pd.read_csv('/content/training_resultsAdhocDQNN.csv')
genomic_df = pd.read_csv('/content/training_resultsGenomicDQNN.csv')
breastcancer_df = pd.read_csv('/content/training_results_BreatCancerDQNN.csv')

# Dictionary to hold the dataframes
datasets = {
    "Iris": iris_df,
    "Adhoc": adhoc_df,
    "Genomic": genomic_df,
    "BreastCancer": breastcancer_df
}

# Define colors for each dataset (muted, professional palette)
colors = {
    "Iris": "#2b83ba",          # blue
    "Adhoc": "#fdae61",         # orange
    "Genomic": "#abdda4",       # green
    "BreastCancer": "#d7191c"   # red
}

# Plot 1: Training Accuracy
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Training Accuracy'], label=f'{dataset_name}_DQNN', color=colors[dataset_name])
plt.title('D-QNN Training Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Training Accuracy')
plt.axhline(y=75, color=colors["Iris"], linestyle='--', label='Iris_QNN')
plt.axhline(y=99, color=colors["Adhoc"], linestyle='--', label='Adhoc_QNN ')
plt.axhline(y=70, color=colors["Genomic"], linestyle='--', label='Genomic_QNN ')
plt.axhline(y=82, color=colors["BreastCancer"], linestyle='--', label='BreastCancer_QNN ')
plt.legend(loc='lower right', fontsize=8)
plt.tight_layout()
plt.savefig('D-QNN_Training_Accuracy.png', dpi=300)  # Save plot
plt.show()


# Plot 2: Test Accuracy
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Test Accuracy'],label=f'{dataset_name}_DQNN', color=colors[dataset_name])


plt.title('D-QNN Test Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Test Accuracy')
plt.axhline(y=40, color=colors["Iris"], linestyle='--', label='Iris_QNN ')
plt.axhline(y=96.67, color=colors["Adhoc"], linestyle='--', label='Adhoc_QNN ')
plt.axhline(y=75, color=colors["Genomic"], linestyle='--', label='Genomic_QNN ')
plt.axhline(y=80, color=colors["BreastCancer"], linestyle='--', label='BreastCancer_QNN ')
plt.legend(loc='lower right', fontsize=8)
plt.tight_layout()
plt.savefig('D-QNN_Test_Accuracy.png', dpi=300)  # Save plot
plt.show()

# Plot 3: Objective Function Value
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Objective Function Value'], label=f'{dataset_name} ', color=colors[dataset_name])
plt.title('D-QNN_Objective_Function_Value')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')
plt.legend(loc='lower right',  fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Objective_Function_Value.png', dpi=300)  # Save plot
plt.show()

# Plot 4: Learning Rate
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Learning Rate'], label=f'{dataset_name} ', color=colors[dataset_name])
plt.title('D-QNN_Learning_Rate')
plt.xlabel('Iteration')
plt.ylabel('Learning Rate')
plt.legend(loc='lower right', fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Learning_Rate.png', dpi=300)  # Save plot
plt.show()

# Plot 5: Perturbation Rate
plt.figure(figsize=(6, 4))
for dataset_name, df in datasets.items():
    plt.plot(df['Iteration'], df['Perturbation'], label=f'{dataset_name} ', color=colors[dataset_name])
plt.title('D-QNN_Perturbation_Rate')
plt.xlabel('Iteration')
plt.ylabel('Perturbation Rate')
plt.legend(loc='lower right', fontsize=10)
plt.tight_layout()
plt.savefig('D-QNN_Perturbation_Rate.png', dpi=300)  # Save plot
plt.show()


# Additional Accuracy Comparison

import matplotlib.pyplot as plt

# Data from the table
datasets = ['Adhoc', 'Iris', 'BreastCancer', 'Genomic']
qnn_train_acc = [99, 75, 82, 70]
qnn_test_acc = [96.67, 40, 80, 75]
dqnn_train_acc = [100, 76.25, 86, 79.5]
dqnn_test_acc = [96.67, 60, 82, 83]

# Define a color scheme using purple and cyan for good contrast
qnn_color = "#9467bd"  # Purple for QNN
dqnn_color = "#17becf"  # Cyan for DQNN

# Create a plot for Training Accuracy
plt.figure(figsize=(6, 4))
plt.plot(datasets, qnn_train_acc, marker='o', linestyle='-', label='QNN', color=qnn_color)
plt.plot(datasets, dqnn_train_acc, marker='o', linestyle='--', label='DQNN', color=dqnn_color)
plt.title('Comparison of QNN and DQNN Training Accuracy Across Datasets', fontsize=12)
plt.xlabel('Dataset', fontsize=10)
plt.ylabel('Training Accuracy (%)', fontsize=10)
plt.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# Create a plot for Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(datasets, qnn_test_acc, marker='o', linestyle='-', label='QNN', color=qnn_color)
plt.plot(datasets, dqnn_test_acc, marker='o', linestyle='--', label='DQNN', color=dqnn_color)
plt.title('Comparison of QNN and DQNN Test Accuracy Across Datasets', fontsize=12)
plt.xlabel('Dataset', fontsize=10)
plt.ylabel('Test Accuracy (%)', fontsize=10)
plt.legend(loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()
